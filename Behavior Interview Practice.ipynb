# %%
import openpyxl
import time
import random



# READ: Workbook, Sheet, Cell
Prac_BI = openpyxl.load_workbook("Behavior_Interview.xlsx", read_only=True)
sheet_content = Prac_BI['Sheet7']
sheet_seize_biz_oppo = Prac_BI['Sheet1']
sheet_drive_collab_inclu = Prac_BI['Sheet2']
sheet_demonstrate_curio_innov = Prac_BI['Sheet3']
sheet_strive_contin_improve = Prac_BI['Sheet4']
sheet_deliver_qual = Prac_BI['Sheet5']
sheet_exercise_prof_judg = Prac_BI['Sheet6']

# WELCOME 
print("\nWelcome to the Behaviour Interview Practice! \nThis is your new step for preparing job application.\nLet'start the NEW JOURNEY!")
time.sleep(2)

# START - Chose Categories
request1 = format(input('''\nWhich kind of Behaviour Interview Question do you want to practice?
1.Seize Business Opportunities
2.Drive Collaboration & Inclusion
3.Demonstrate Curiosity& Innovation
4.Strive Continual Improvement
5.Deliver Qualities
6.Exercise Professional Judgment\n''')).upper()

# Seize Business Opportunites
if request1 == '1':
    
    description1 = sheet_content.cell(2,3)
    key_capacity1 = sheet_content.cell(2,4)
    print("\nSeize Business Opportunities\n"+"Category Description:\n"+description1.value+"\nKey Capacity:\n"+key_capacity1.value)
    time.sleep(10)
    
    request1_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list1 = list(range(2, sheet_seize_biz_oppo.max_row))
    
    while len(list1) > 0:

        # random range
        questionNo1 = random.choice(list1)
        question1 = sheet_seize_biz_oppo.cell(questionNo1, 2)
        note1 = sheet_seize_biz_oppo.cell(questionNo1, 3)
        positive_indicators1 = sheet_content.cell(2,5)
        negative_indicators1 = sheet_content.cell(2,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo1) + ": " + question1.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
        
        # Positive or Negative Indicators Example
        request1_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request1_3 == 'P':
            print("\nPositive:\n" + positive_indicators1.value)
            time.sleep(10)
        
            request1_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request1_3 == 'N':
            print("\nNegative:\n" + negative_indicators1.value)
            time.sleep(10)
            
            request1_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request1_3 == 'B':
            print("\nPositive:\n" + positive_indicators1.value+"Negative:\n"+negative_indicators1.value)
            time.sleep(10)
            
            request1_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
       
        list1.remove(questionNo1)
    
    # FINISH
    if len(list1) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Seize Business Opportunities'Problem Finished! ")



# Drive Collaboration & Inclusion 
elif request1 =='2':
    
    description2 = sheet_content.cell(3,3)
    key_capacity2 = sheet_content.cell(3,4)
    print("\nDrive Collaboration & Inclusion\n"+"Category Description:\n"+description2.value+"\nKey Capacity:\n"+key_capacity2.value)
    time.sleep(10)
    
    request2_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list2 = list(range(2, sheet_drive_collab_inclu.max_row))
    
    while len(list2) > 0:

        # random range
        questionNo2 = random.choice(list2)
        question2 = sheet_drive_collab_inclu.cell(questionNo2, 2)
        note2 = sheet_drive_collab_inclu.cell(questionNo2, 3)
        positive_indicators2 = sheet_content.cell(3,5)
        negative_indicators2 = sheet_content.cell(3,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo2) + ": " + question2.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
    
        # Positive or Negative Indicators Example
        request2_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request2_3 == 'P':
            print("\nPositive:\n" + positive_indicators2.value)
            time.sleep(10)
        
            request2_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request2_3 == 'N':
            print("\nNegative:\n" + negative_indicators2.value)
            time.sleep(10)
            
            request2_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request2_3 == 'B':
            print("\nPositive:\n" + positive_indicators2.value+"Negative:\n"+negative_indicators2.value)
            time.sleep(10)
            
            request2_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        list2.remove(questionNo2)
                                
    # FINISH
    if len(list2) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Drive Collaboration & Inclusion'Problem Finished! ")

                                
                                
# Demostrate Curiosity & Innovation
elif request1 =='3':
    
    description3 = sheet_content.cell(4,3)
    key_capacity3 = sheet_content.cell(4,4)
    print("\nDemostrate Curiosity & Innovation\n"+"Category Description:\n"+description3.value+"\nKey Capacity:\n"+key_capacity3.value)
    time.sleep(10)
    
    request3_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list3 = list(range(2, sheet_seize_biz_oppo.max_row))
    
    while len(list3) > 0:

        # random range
        questionNo3 = random.choice(list3)
        question3 = sheet_demonstrate_curio_innov.cell(questionNo3, 2)
        note3 = sheet_demonstrate_curio_innov.cell(questionNo3, 3)
        positive_indicators3 = sheet_content.cell(4,5)
        negative_indicators3 = sheet_content.cell(4,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo3) + ": " + question3.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
        
        # Positive or Negative Indicators Example
        request3_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request3_3 == 'P':
            print("\nPositive:\n" + positive_indicators3.value)
            time.sleep(10)
        
            request3_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request3_3 == 'N':
            print("\nNegative:\n" + negative_indicators3.value)
            time.sleep(10)
            
            request3_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request3_3 == 'B':
            print("\nPositive:\n" + positive_indicators3.value+"Negative:\n"+negative_indicators3.value)
            time.sleep(10)
            
            request3_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
       
        list3.remove(questionNo3)
    
    # FINISH
    if len(list3) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Demostrate Curiosity & Innovation'Problem Finished! ")

                                
                                
                                
# Strive for Continual Improvement
elif request1 =='4':
    
    description4 = sheet_content.cell(5,3)
    key_capacity4 = sheet_content.cell(5,4)
    print("\nStrive for Continual Improvement\n"+"Category Description:\n"+description4.value+"\nKey Capacity:\n"+key_capacity4.value)
    time.sleep(10)
    
    request4_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list4 = list(range(2, sheet_strive_contin_improve.max_row))
    
    while len(list4) > 0:

        # random range
        questionNo4 = random.choice(list4)
        question4 = sheet_strive_contin_improve.cell(questionNo4, 2)
        note4 = sheet_strive_contin_improve.cell(questionNo4, 3)
        positive_indicators4 = sheet_content.cell(5,5)
        negative_indicators4 = sheet_content.cell(5,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo4) + ": " + question4.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
        
        # Positive or Negative Indicators Example
        request4_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request4_3 == 'P':
            print("\nPositive:\n" + positive_indicators4.value)
            time.sleep(10)
        
            request4_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request4_3 == 'N':
            print("\nNegative:\n" + negative_indicators4.value)
            time.sleep(10)
            
            request4_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request4_3 == 'B':
            print("\nPositive:\n" + positive_indicators4.value+"Negative:\n"+negative_indicators4.value)
            time.sleep(10)
            
            request4_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
       
        list4.remove(questionNo4)
    
    # FINISH
    if len(list4) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Strive for Continual Improvement'Problem Finished! ")

                                
                                
                                
# Deliver Quality
elif request1 =='5':
    
    description5 = sheet_content.cell(6,3)
    key_capacity5 = sheet_content.cell(6,4)
    print("\nDeliver Quality\n"+"Category Description:\n"+description5.value+"\nKey Capacity:\n"+key_capacity5.value)
    time.sleep(10)
    
    request5_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list5 = list(range(2, sheet_deliver_qual.max_row))
    
    while len(list5) > 0:

        # random range
        questionNo5 = random.choice(list5)
        question5 = sheet_deliver_qual.cell(questionNo5, 2)
        note5 = sheet_deliver_qual.cell(questionNo5, 3)
        positive_indicators5 = sheet_content.cell(6,5)
        negative_indicators5 = sheet_content.cell(6,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo5) + ": " + question5.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
        
        # Positive or Negative Indicators Example
        request5_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request5_3 == 'P':
            print("\nPositive:\n" + positive_indicators5.value)
            time.sleep(10)
        
            request5_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request5_3 == 'N':
            print("\nNegative:\n" + negative_indicators5.value)
            time.sleep(10)
            
            request5_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request5_3 == 'B':
            print("\nPositive:\n" + positive_indicators5.value+"Negative:\n"+negative_indicators5.value)
            time.sleep(10)
            
            request5_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        list5.remove(questionNo5)
    
    # FINISH
    if len(list5) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Deliver Quality'Problem Finished! ")
    
                                
                                
                                
# Excercise Professional Judgment
elif request1 =='6':
    
    description6 = sheet_content.cell(7,3)
    key_capacity6 = sheet_content.cell(7,4)
    print("\nExcercise Professional Judgment\n"+"Category Description:\n"+description6.value+"\nKey Capacity:\n"+key_capacity6.value)
    time.sleep(10)
    
    request6_2 = format(input("\nWhen you are ready for the question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
    
    #Practice
    #cycle
    list6 = list(range(2, sheet_exercise_prof_judg.max_row))
    
    while len(list6) > 0:

        # random range
        questionNo6 = random.choice(list6)
        question6 = sheet_exercise_prof_judg.cell(questionNo6, 2)
        note6 = sheet_exercise_prof_judg.cell(questionNo6, 3)
        positive_indicators6 = sheet_content.cell(7,5)
        negative_indicators6 = sheet_content.cell(7,6)

        #  Question (random inside category)
        print("\nQ" + str(questionNo6) + ": " + question6.value)
        time.sleep(90)
        print("\n1:30 TIME UP")
        
        # Positive or Negative Indicators Example
        request6_3 = format(input("Do you want to check the Positive or Negative Indicators Examples?\nPositive(P)/Negative(N)/Both(B)/Skip(S)\n")).upper()

        if request6_3 == 'P':
            print("\nPositive:\n" + positive_indicators6.value)
            time.sleep(10)
        
            request6_4 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
        
        
        elif request6_3 == 'N':
            print("\nNegative:\n" + negative_indicators6.value)
            time.sleep(10)
            
            request6_5 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()

        
        elif request6_3 == 'B':
            print("\nPositive:\n" + positive_indicators6.value+"Negative:\n"+negative_indicators6.value)
            time.sleep(10)
            
            request6_6 = format(input("\nWhen you are ready for the next question, please input ‘START’\nInterview Time Limitation 90sec\n")).upper()
       
        
        list6.remove(questionNo6)
                    
    # FINISH
    if len(list6) == 0:
        print("\nwow~ ⊙o⊙! Practice of 'Excercise Professional Judgment'Problem Finished! ")
